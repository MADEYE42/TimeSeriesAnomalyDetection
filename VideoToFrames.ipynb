# %%
import cv2
import os
from glob import glob

# 👇 Set this to your dataset root folder (containing activity folders)
dataset_root = 'Activities'  # Replace with the actual path in your Colab environment

# 👇 Output folder where annotated frames will be saved
output_root = './annotated_frames'
os.makedirs(output_root, exist_ok=True)

# 👇 Define your list of activity folders
activities = [
    'Falling', 'Jumping', 'Lying', 'Running', 'Shaking',
    'Sitting', 'Standing', 'Walking',
    'Walking Downstairs', 'Walking Upstairs'
]

# Normalize folder names
def normalize_activity_name(name):
    return name.replace(" ", "_").lower()

# Loop through each activity folder
for activity in activities:
    activity_path = os.path.join(dataset_root, activity)
    if not os.path.isdir(activity_path):
        print(f"Skipping (not a folder): {activity_path}")
        continue

    # Output folder for this activity
    activity_output_folder = os.path.join(output_root, activity)
    os.makedirs(activity_output_folder, exist_ok=True)

    # Process each video inside this folder
    video_files = glob(os.path.join(activity_path, '*.mp4'))  # or .avi, .mov
    for video_path in video_files:
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"❌ Failed to open video: {video_path}")
            continue

        fps = cap.get(cv2.CAP_PROP_FPS)
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        frame_count = 0
        saved_frame_count = 0

        while True:
            success, frame = cap.read()
            if not success:
                break

            current_time_ms = cap.get(cv2.CAP_PROP_POS_MSEC)
            if int(current_time_ms) % 1000 < 40:
                annotated_frame = frame.copy()
                cv2.putText(annotated_frame, activity.upper(), (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

                timestamp = int(current_time_ms / 1000)
                normalized_name = normalize_activity_name(activity)
                filename = f"{normalized_name}_{video_name}_{timestamp:04d}.jpg"
                filepath = os.path.join(activity_output_folder, filename)

                cv2.imwrite(filepath, annotated_frame)
                saved_frame_count += 1

            frame_count += 1

        cap.release()
        print(f"✅ {activity} | {os.path.basename(video_path)}: {saved_frame_count} frames saved")

print("\n🎉 Frame extraction and annotation complete!")
# Out:
# ✅ Falling | Fall (1).mp4: 13 frames saved
# ✅ Falling | Fall (26).mp4: 8 frames saved
# ✅ Falling | Fall (27).mp4: 16 frames saved
# ✅ Falling | Fall (28).mp4: 12 frames saved
# ✅ Falling | Fall (29).mp4: 12 frames saved
# ✅ Falling | Fall (30).mp4: 7 frames saved
# ✅ Falling | Fall (31).mp4: 5 frames saved
# ✅ Falling | Fall (32).mp4: 18 frames saved
# ✅ Falling | Fall (33).mp4: 12 frames saved
# ✅ Falling | Fall (34).mp4: 20 frames saved
# ✅ Falling | Fall (35).mp4: 8 frames saved
# ✅ Falling | Fall (36).mp4: 5 frames saved
# ✅ Falling | Fall (37).mp4: 10 frames saved
# ✅ Falling | Fall (38).mp4: 9 frames saved
# ✅ Falling | Fall (39).mp4: 11 frames saved
# ✅ Falling | Fall (40).mp4: 15 frames saved
# ✅ Falling | Fall (41).mp4: 24 frames saved
# ✅ Falling | Fall (42).mp4: 12 frames saved
# ✅ Falling | Fall (43).mp4: 15 frames saved
# ✅ Falling | Fall (44).mp4: 15 frames saved
# ✅ Falling | Fall (45).mp4: 20 frames saved
# ✅ Falling | Fall (46).mp4: 9 frames saved
# ✅ Falling | Fall (47).mp4: 11 frames saved
# ✅ Falling | Fall (48).mp4: 12 frames saved
# ✅ Falling | Fall (49).mp4: 18 frames saved
# ✅ Falling | Fall (50).mp4: 18 frames saved
# ✅ Falling | Fall (51).mp4: 10 frames saved
# ✅ Falling | Fall (52).mp4: 18 frames saved
# ✅ Falling | Fall (53).mp4: 6 frames saved
# ✅ Jumping | Exercise (1).mp4: 30 frames saved
# ✅ Jumping | Exercise (10).mp4: 35 frames saved
# ✅ Jumping | Exercise (11).mp4: 33 frames saved
# ✅ Jumping | Exercise (12).mp4: 12 frames saved
# ✅ Jumping | Exercise (13).mp4: 10 frames saved
# ✅ Jumping | Exercise (8).mp4: 33 frames saved
# ✅ Jumping | Exercise (9).mp4: 14 frames saved
# ✅ Lying | Lying (1).mp4: 24 frames saved
# ✅ Lying | Lying (10).mp4: 33 frames saved
# ✅ Lying | Lying (11).mp4: 12 frames saved
# ✅ Lying | Lying (2).mp4: 12 frames saved
# ✅ Lying | Lying (3).mp4: 13 frames saved
# ✅ Lying | Lying (4).mp4: 12 frames saved
# ✅ Lying | Lying (5).mp4: 12 frames saved
# ✅ Lying | Lying (6).mp4: 21 frames saved
# ✅ Lying | Lying (7).mp4: 11 frames saved
# ✅ Lying | Lying (8).mp4: 36 frames saved
# ✅ Lying | Lying (9).mp4: 33 frames saved
# ✅ Running | Running (1).mp4: 12 frames saved
# ✅ Running | Running (10).mp4: 20 frames saved
# ✅ Running | Running (11).mp4: 9 frames saved
# ✅ Running | Running (12).mp4: 12 frames saved
# ✅ Running | Running (13).mp4: 12 frames saved
# ✅ Running | Running (14).mp4: 30 frames saved
# ✅ Running | Running (15).mp4: 30 frames saved
# ✅ Running | Running (16).mp4: 27 frames saved
# ✅ Running | Running (17).mp4: 13 frames saved
# ✅ Running | Running (18).mp4: 15 frames saved
# Skipping (not a folder): Activities\Shaking
# ✅ Sitting | Sitting (1).mp4: 33 frames saved
# ✅ Sitting | Sitting (16).mp4: 13 frames saved
# ✅ Sitting | Sitting (17).mp4: 11 frames saved
# ✅ Sitting | Sitting (18).mp4: 12 frames saved
# ✅ Sitting | Sitting (19).mp4: 12 frames saved
# ✅ Sitting | Sitting (20).mp4: 11 frames saved
# ✅ Sitting | Sitting (21).mp4: 10 frames saved
# ✅ Sitting | Sitting (22).mp4: 22 frames saved
# ✅ Sitting | Sitting (23).mp4: 12 frames saved
# ✅ Sitting | Sitting (24).mp4: 15 frames saved
# ✅ Sitting | Sitting (25).mp4: 33 frames saved
# ✅ Sitting | Sitting (26).mp4: 33 frames saved
# ✅ Sitting | Sitting (27).mp4: 33 frames saved
# ✅ Sitting | Sitting (28).mp4: 33 frames saved
# ✅ Sitting | Sitting (29).mp4: 12 frames saved
# ✅ Sitting | Sitting (30).mp4: 14 frames saved
# ✅ Standing | Standing (1).mp4: 12 frames saved
# ✅ Standing | Standing (12).mp4: 36 frames saved
# ✅ Standing | Standing (13).mp4: 13 frames saved
# ✅ Standing | Standing (14).mp4: 11 frames saved
# ✅ Standing | Standing (15).mp4: 13 frames saved
# ✅ Standing | Standing (16).mp4: 12 frames saved
# ✅ Standing | Standing (17).mp4: 14 frames saved
# ✅ Standing | Standing (18).mp4: 10 frames saved
# ✅ Standing | Standing (19).mp4: 11 frames saved
# ✅ Standing | Standing (20).mp4: 11 frames saved
# ✅ Standing | Standing (21).mp4: 14 frames saved
# ✅ Standing | Standing (22).mp4: 15 frames saved
# ✅ Walking | Walking (1).mp4: 31 frames saved
# ✅ Walking | Walking (12).mp4: 12 frames saved
# ✅ Walking | Walking (13).mp4: 11 frames saved
# ✅ Walking | Walking (14).mp4: 11 frames saved
# ✅ Walking | Walking (15).mp4: 22 frames saved
# ✅ Walking | Walking (16).mp4: 9 frames saved
# ✅ Walking | Walking (17).mp4: 12 frames saved
# ✅ Walking | Walking (18).mp4: 11 frames saved
# ✅ Walking | Walking (19).mp4: 32 frames saved
# ✅ Walking | Walking (20).mp4: 26 frames saved
# ✅ Walking | Walking (21).mp4: 33 frames saved
# ✅ Walking | Walking (22).mp4: 15 frames saved
# ✅ Walking Downstairs | Walking Downstairs (1).mp4: 33 frames saved
# ✅ Walking Downstairs | Walking Downstairs (10).mp4: 33 frames saved
# ✅ Walking Downstairs | Walking Downstairs (11).mp4: 26 frames saved
# ✅ Walking Downstairs | Walking Downstairs (12).mp4: 16 frames saved
# ✅ Walking Downstairs | Walking Downstairs (13).mp4: 22 frames saved
# ✅ Walking Downstairs | Walking Downstairs (14).mp4: 10 frames saved
# ✅ Walking Downstairs | Walking Downstairs (15).mp4: 9 frames saved
# ✅ Walking Downstairs | Walking Downstairs (16).mp4: 18 frames saved
# ✅ Walking Downstairs | Walking Downstairs (17).mp4: 11 frames saved
# ✅ Walking Downstairs | Walking Downstairs (18).mp4: 15 frames saved
# ✅ Walking Upstairs | Walking Upstairs (1).mp4: 14 frames saved
# ✅ Walking Upstairs | Walking Upstairs (10).mp4: 10 frames saved
# ✅ Walking Upstairs | Walking Upstairs (6).mp4: 21 frames saved
# ✅ Walking Upstairs | Walking Upstairs (7).mp4: 33 frames saved
# ✅ Walking Upstairs | Walking Upstairs (8).mp4: 18 frames saved
# ✅ Walking Upstairs | Walking Upstairs (9).mp4: 17 frames saved
#
# 🎉 Frame extraction and annotation complete!
